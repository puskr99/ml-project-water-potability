# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/water.csv')
data.head(2)
# Out:
#    Unnamed: 0  Canal_id  year       Canal_name Sample_water_point  TEMP. (oC)  \
# 0           1      12.0  2561  คลองคูเมืองเดิม         ปตร.ราชินี        25.0
# 1           2      13.0  2561  คลองคูเมืองเดิม      หน้ากรมที่ดิน        25.0
#
#      pH  DO (mg/l)  H2S (mg/l)  BOD (mg/l)  COD (mg/l)  SS (mg/l)  TKN (mg/l)  \
# 0   8.0        2.7         0.0         5.0        42.0       26.0         2.2
# 1   8.1        2.4         0.0         5.0        53.0       25.0         1.7
#
#    NH3N (mg/l)  NO2 (mg/l)  NO3 (mg/l)  T-P (mg/l)  T.Coliform (col/100ml)  \
# 0          0.9         0.0         2.2         0.1                930000.0
# 1          0.6         0.0         2.2         0.1              11000000.0
#
#                              Sample_water_point (EN)         Canal_name (EN)
# 0  Her Royal Highness Princess Maha Chakri Sirind...  Khlong Khu Mueang Derm
# 1                           Department of Lands page  Khlong Khu Mueang Derm

# %%
data.shape
# Out:
# (917, 20)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Canal_id', 'year', 'Canal_name', 'Sample_water_point',
#        'TEMP. (oC)', '  pH', 'DO (mg/l)', 'H2S (mg/l)', 'BOD (mg/l)',
#        'COD (mg/l)', 'SS (mg/l)', 'TKN (mg/l)', 'NH3N (mg/l)', 'NO2 (mg/l)',
#        'NO3 (mg/l)', 'T-P (mg/l)', 'T.Coliform (col/100ml)',
#        'Sample_water_point (EN)', 'Canal_name (EN)'],
#       dtype='object')

# %%
cols = {
    'Unnamed: 0': 'Index',
    'Canal_id': 'CID',
    'year': 'Year',
    'Canal_name': 'CN',
    'Sample_water_point': 'WSP',
    'TEMP. (oC)': 'Temp',
    '  pH': 'pH',
    'DO (mg/l)': 'DO',
    'H2S (mg/l)': 'HS',
    'BOD (mg/l)': 'BO',
    'COD (mg/l)': 'CO',
    'SS (mg/l)': 'SS',
    'TKN (mg/l)': 'TKN',
    'NH3N (mg/l)': 'AN',
    'NO2 (mg/l)': 'NO2N',
    'NO3 (mg/l)': 'NO3N',
    'T-P (mg/l)': 'TP',
    'T.Coliform (col/100ml)': 'TC',
    'Sample_water_point (EN)': 'WSPEN',
    'Canal_name (EN)': 'CNEN'
}


data = data.rename(columns=cols)
data.columns
# Out:
# Index(['Index', 'CID', 'Year', 'CN', 'WSP', 'Temp', 'pH', 'DO', 'HS', 'BO',
#        'CO', 'SS', 'TKN', 'AN', 'NO2N', 'NO3N', 'TP', 'TC', 'WSPEN', 'CNEN'],
#       dtype='object')

# %%
data['CNEN'].value_counts()
# Out:
# CNEN
# Khlong Saen Saep                               33
# Khlong Prem Prachakorn                         24
# Khlong Chong Nonsi                             18
# Khlong Rob Krung                               18
# Khlong Phlapphla                               18
#                                                ..
# Khlong Bang Luang                               1
# Khlong Phra Rajadamri 1 (Khlong Bueng Phai)     1
# Khlong Phraya Suren                             1
# Orachon Canal                                   1
# Khlong Tanod                                    1
# Name: count, Length: 168, dtype: int64

# %% [markdown]
# **Data Preprocessing**

# %%
data.describe()
# Out:
#             Index          CID         Year        Temp          pH  \
# count  917.000000   917.000000   917.000000  917.000000  917.000000
# mean   459.000000   729.759324  2562.008724   28.694329    7.242007
# std    264.859397   553.978537     0.820008    1.845115    0.462830
# min      1.000000    12.000000  2561.000000    0.000000    0.000000
# 25%    230.000000   221.000000  2561.000000   28.500000    7.130000
# 50%    459.000000   591.000000  2562.000000   29.000000    7.290000
# 75%    688.000000  1191.000000  2563.000000   29.300000    7.400000
# max    917.000000  1822.000000  2563.000000   31.900000    9.100000
#
#                DO          HS          BO          CO          SS         TKN  \
# count  917.000000  917.000000  917.000000  917.000000  917.000000  917.000000
# mean     1.667045    0.179804   12.802672   64.103762   21.953719    7.999945
# std      1.282984    0.389665    9.397183   22.350496   17.194847    5.133194
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.510000    0.000000    6.250000   51.000000   12.000000    4.100000
# 50%      1.600000    0.000000    9.800000   60.500000   17.000000    7.100000
# 75%      2.600000    0.200000   15.830000   72.100000   26.000000   10.800000
# max      9.700000    5.000000   84.500000  202.000000  148.300000   39.800000
#
#                AN        NO2N        NO3N          TP             TC
# count  917.000000  917.000000  917.000000  917.000000   9.170000e+02
# mean     4.358997    0.146205    2.123228    0.947895  2.181025e+118
# std      3.600244    0.131068    0.692240    0.519764  6.604582e+119
# min      0.000000    0.000000    0.000000    0.000000   0.000000e+00
# 25%      1.500000    0.020000    1.700000    0.520000   1.220000e+08
# 50%      3.460000    0.110000    2.000000    0.900000   1.530000e+10
# 75%      6.100000    0.210000    2.500000    1.250000   2.100000e+12
# max     23.330000    0.730000    8.600000    3.530000  2.000000e+121

# %% [markdown]
# Check for column types.

# %%
data.dtypes
# Out:
# Index      int64
# CID      float64
# Year       int64
# CN        object
# WSP       object
# Temp     float64
# pH       float64
# DO       float64
# HS       float64
# BO       float64
# CO       float64
# SS       float64
# TKN      float64
# AN       float64
# NO2N     float64
# NO3N     float64
# TP       float64
# TC       float64
# WSPEN     object
# CNEN      object
# dtype: object

# %% [markdown]
# Drop unnecessary columns from the dataset.

# %%
# We have translated Canal Name and Water Source Point. So drop those columns in thai language.
data.drop(columns=['Index', 'CN', 'WSP'], inplace=True)

# %%
data.dtypes
# Out:
# CID      float64
# Year       int64
# Temp     float64
# pH       float64
# DO       float64
# HS       float64
# BO       float64
# CO       float64
# SS       float64
# TKN      float64
# AN       float64
# NO2N     float64
# NO3N     float64
# TP       float64
# TC       float64
# WSPEN     object
# CNEN      object
# dtype: object

# %% [markdown]
# Check for null values in the dataset.

# %%
data.isna().sum()
# Out:
# CID      0
# Year     0
# Temp     0
# pH       0
# DO       0
# HS       0
# BO       0
# CO       0
# SS       0
# TKN      0
# AN       0
# NO2N     0
# NO3N     0
# TP       0
# TC       0
# WSPEN    0
# CNEN     0
# dtype: int64

# %% [markdown]
# Seems we have no null values in our dataset.

# %%
data.head()
# Out:
#     CID  Year  Temp   pH   DO   HS   BO    CO    SS  TKN   AN  NO2N  NO3N  \
# 0  12.0  2561  25.0  8.0  2.7  0.0  5.0  42.0  26.0  2.2  0.9  0.00   2.2
# 1  13.0  2561  25.0  8.1  2.4  0.0  5.0  53.0  25.0  1.7  0.6  0.00   2.2
# 2  14.0  2561  25.0  8.0  1.7  0.0  5.0  56.0  24.0  2.2  0.6  0.34   2.3
# 3  15.0  2561  25.0  7.9  3.0  0.0  4.0  47.0  17.0  2.8  0.6  0.00   1.9
# 4  16.0  2561  25.0  7.3  1.4  0.0  6.0  36.0   7.0  2.8  0.6  0.14   1.1
#
#     TP          TC                                              WSPEN  \
# 0  0.1    930000.0  Her Royal Highness Princess Maha Chakri Sirind...
# 1  0.1  11000000.0                           Department of Lands page
# 2  0.2   4600000.0       Mother Earth Muay Hair Monument, Sanam Luang
# 3  0.1     30000.0                        Phra Pinklao Police Station
# 4  0.3   1500000.0        Bridge in front of the Ministry of Interior
#
#                      CNEN
# 0  Khlong Khu Mueang Derm
# 1  Khlong Khu Mueang Derm
# 2  Khlong Khu Mueang Derm
# 3  Khlong Khu Mueang Derm
# 4  Khlong Khu Mueang Derm

# %%
data.columns
# Out:
# Index(['CID', 'Year', 'Temp', 'pH', 'DO', 'HS', 'BO', 'CO', 'SS', 'TKN', 'AN',
#        'NO2N', 'NO3N', 'TP', 'TC', 'WSPEN', 'CNEN'],
#       dtype='object')

# %%
# using label encoding for these 4 features
# as they are objects and need to be a real num or a int.

from sklearn.preprocessing import LabelEncoder

features = ["WSPEN", "CNEN"]

for feat in features:
    le = LabelEncoder()
    data[feat] = le.fit_transform(data[feat])

# %%
data.head()
# Out:
#     CID  Year  Temp   pH   DO   HS   BO    CO    SS  TKN   AN  NO2N  NO3N  \
# 0  12.0  2561  25.0  8.0  2.7  0.0  5.0  42.0  26.0  2.2  0.9  0.00   2.2
# 1  13.0  2561  25.0  8.1  2.4  0.0  5.0  53.0  25.0  1.7  0.6  0.00   2.2
# 2  14.0  2561  25.0  8.0  1.7  0.0  5.0  56.0  24.0  2.2  0.6  0.34   2.3
# 3  15.0  2561  25.0  7.9  3.0  0.0  4.0  47.0  17.0  2.8  0.6  0.00   1.9
# 4  16.0  2561  25.0  7.3  1.4  0.0  6.0  36.0   7.0  2.8  0.6  0.14   1.1
#
#     TP          TC  WSPEN  CNEN
# 0  0.1    930000.0     61    61
# 1  0.1  11000000.0     58    61
# 2  0.2   4600000.0    114    61
# 3  0.1     30000.0    155    61
# 4  0.3   1500000.0     28    61

# %%
data['TC'].describe()
# Out:
# count     9.170000e+02
# mean     2.181025e+118
# std      6.604582e+119
# min       0.000000e+00
# 25%       1.220000e+08
# 50%       1.530000e+10
# 75%       2.100000e+12
# max      2.000000e+121
# Name: TC, dtype: float64

# %%
data.dtypes
# Out:
# CID      float64
# Year       int64
# Temp     float64
# pH       float64
# DO       float64
# HS       float64
# BO       float64
# CO       float64
# SS       float64
# TKN      float64
# AN       float64
# NO2N     float64
# NO3N     float64
# TP       float64
# TC       float64
# WSPEN      int64
# CNEN       int64
# dtype: object

# %%
data.head(3)
# Out:
#     CID  Year  Temp   pH   DO   HS   BO    CO    SS  TKN   AN  NO2N  NO3N  \
# 0  12.0  2561  25.0  8.0  2.7  0.0  5.0  42.0  26.0  2.2  0.9  0.00   2.2
# 1  13.0  2561  25.0  8.1  2.4  0.0  5.0  53.0  25.0  1.7  0.6  0.00   2.2
# 2  14.0  2561  25.0  8.0  1.7  0.0  5.0  56.0  24.0  2.2  0.6  0.34   2.3
#
#     TP          TC  WSPEN  CNEN
# 0  0.1    930000.0     61    61
# 1  0.1  11000000.0     58    61
# 2  0.2   4600000.0    114    61

# %% [markdown]
# **Feature Engineering**

# %% [markdown]
# Here lets engineer a new feature called ISQA (Simple Water Quality Index) using the formula
# - ISQA = ITEMP * (IBOD + ITSS + IDO)
# where,
#     - ITEMP = Water Temperature Index
#     - IBOD = Biological Oxygen Demand Index
#     - ITSS = Total Suspended Solids Index
#     - IDO = Dissolved Oxygen Index
#     - ICOND = Conductivity of Water Index

# %%
# Calculate TDS and COND
data['TDS'] = (
    0.6 * data['NO3N'] +
    0.8 * data['NO2N'] +
    0.5 * data['TKN'] +
    0.7 * data['AN'] +
    0.9 * data['TP']
)


# Scale TDS for realistic COND (200–1500 μS/cm)
data['TDS'] = data['TDS'] * 50
data['COND'] = 0.7 * data['TDS']

def calculate_isqa(row):
    # Extract parameters from the row
    temperature = row['Temp']
    bod = row['BO']
    tss = row['SS']
    do = row['DO']
    cond = row['COND']
    
    # Temperature Index (ITEMP)
    if temperature <= 20:
        itemp = 1
    else:
        itemp = max(0, 1 - 0.05 * (temperature - 20))
    
    # Biological Oxygen Demand Index (IBOD)
    if bod == 0:
        ibod = 30
    elif 0 < bod <= 12:
        ibod = max(0, 30 - 2.5 * bod)
    else:
        ibod = 0
    
    # Total Suspended Solids Index (ITSS)
    if tss == 0:
        itss = 25
    elif 0 < tss <= 250:
        itss = max(0, 25 - 0.1 * tss)
    else:
        itss = 0
    
    # Dissolved Oxygen Index (IDO)
    if do >= 10:
        ido = 25
    elif 0 < do < 10:
        ido = 2.5 * do
    else:
        ido = 0
    
    # Conductivity Index (ICOND)
    if cond <= 200:
        icond = 20
    elif 200 < cond <= 4000:
        icond = max(0, 20 - (20 / 3800) * (cond - 200))
    else:
        icond = 0
    
    # ISQA Calculation
    isqa = itemp * (ibod + itss + ido + icond)
    return isqa

data['ISQA'] = data.apply(calculate_isqa, axis=1)

# %%
data['ISQA'].describe()
# Out:
# count    917.000000
# mean      30.035712
# std        6.566263
# min       16.112684
# 25%       24.683116
# 50%       29.271258
# 75%       34.832976
# max       75.000000
# Name: ISQA, dtype: float64

# %%
# # From water quality index (WQI) calculate potability and classify as 2 (safe), 1 (potentially unsafe), 0(unsafe)
# def calc_water_potability(m):
#     if m > 75:
#         return 2
    
#     if m > 50:
#         return 1
    
#     return 0

# data['target'] = data['ISQA'].apply(calc_water_potability)
# data['target'].value_counts()

# %% [markdown]
# Box plot of `target` variable and `NO2N` value of water.

# %%
sns.boxplot(x='ISQA', y='NO2N', data=data)
plt.xticks(rotation=45)
plt.title('Box Plot of Numerical vs Categorical Data')
plt.show()

# %% [markdown]
# Swarm plot for numerical data `pH` and categorical data `target`

# %%
sns.swarmplot(x='ISQA', y='pH', data=data)
plt.xticks(rotation=45)
plt.title('Swarm Plot of Numerical vs Categorical Data')
plt.show()
# Out:
# /home/puskr/ml_project/ml-project-water-potability/.venv/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/puskr/ml_project/ml-project-water-potability/.venv/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Pair plot between ph value of water and Ammonia Nitrate in water.

# %%
sns.pairplot(data=data[['pH', 'AN']])
plt.suptitle('Pair Plot of pH and AN', y=1.02)
plt.show()

# %%
feats = data[['Temp', 'DO', 'BO', 'CO', 'SS']]

sns.pairplot(feats, diag_kind='hist')

# %%
# plt.figure(figsize=(15, 15))
# sns.heatmap(data=data.drop(columns=['CID', 'BO', 'SS', 'Temp', 'DO']).corr(numeric_only=True), annot=True)
# plt.show()

# %%
data['ISQA'].value_counts()
# Out:
# ISQA
# 75.000000    3
# 35.695000    3
# 38.998400    2
# 38.940000    2
# 35.282500    2
#             ..
# 38.865400    1
# 28.605035    1
# 27.595995    1
# 27.101477    1
# 32.723695    1
# Name: count, Length: 902, dtype: int64

# %%
data.columns
# Out:
# Index(['CID', 'Year', 'Temp', 'pH', 'DO', 'HS', 'BO', 'CO', 'SS', 'TKN', 'AN',
#        'NO2N', 'NO3N', 'TP', 'TC', 'WSPEN', 'CNEN', 'TDS', 'COND', 'ISQA'],
#       dtype='object')

# %% [markdown]
# **Feature Selection**

# %%
data['TC'] = np.log1p(data['TC'])  # log1p handles zeros safely

# %%
# Compute the correlation matrix
corr_matrix = data[['pH', 'CO', 'HS', 'TC', 'SS', 'ISQA']].corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix Including Target Variable")
plt.show()

# %%
X = data[ ['pH', 'CO', 'HS', 'TC', 'SS'] ]

y = data['ISQA']

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.15, random_state=42)

# %%
def outlier_count(col, data = X_train):
    
    # calculate your 25% quatile and 75% quatile
    q75, q25 = np.percentile(data[col], [75, 25])
    
    # calculate your inter quatile
    iqr = q75 - q25
    
    # min_val and max_val
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    
    # count number of outliers, which are the data that are less than min_val or more than max_val calculated above
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    
    # calculate the percentage of the outliers
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    
    if(outlier_count > 0):
        print("\n"+15*'-' + col + 15*'-'+"\n")
        print('Number of outliers: {}'.format(outlier_count))
        print('Percent of data that is outlier: {}%'.format(outlier_percent))

        return [min_val, max_val]
    
    return []

# %%
# removing the outliers from the X_train columns using the bounds
for col in X_train.columns:
    bounds = []
    bounds = outlier_count(col)
    if len(bounds) == 0:
        continue
    
    X_train[col] = X_train[col].clip(lower=bounds[0], upper=bounds[1])
# Out:
# ---------------pH---------------
#
# Number of outliers: 15
# Percent of data that is outlier: 1.93%
#
# ---------------CO---------------
#
# Number of outliers: 34
# Percent of data that is outlier: 4.36%
#
# ---------------HS---------------
#
# Number of outliers: 73
# Percent of data that is outlier: 9.37%
#
# ---------------TC---------------
#
# Number of outliers: 4
# Percent of data that is outlier: 0.51%
#
# ---------------SS---------------
#
# Number of outliers: 58
# Percent of data that is outlier: 7.45%

# %% [markdown]
# Scale the features using standard scalar for faster convergence.

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X_train_resampled = ss.fit_transform(X_train)
X_test = ss.fit_transform(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import Lasso, Ridge

algorithms = {
    "Lasso": Lasso(random_state=42),
    "Ridge": Ridge(random_state=42),
    "SVR": SVR(),
    "Random Forest": RandomForestRegressor(random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42)
}

# %%
from sklearn.model_selection import KFold, cross_val_score

#defining splits
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

for name, model in algorithms.items():
    cv_scores = cross_val_score(model, X_train_resampled, y_train, cv=kfold, scoring='neg_mean_squared_error')
    # Convert neg MSE to RMSE
    # rmse_scores = np.sqrt(-cv_scores)

    print(f"{name} - Score: {cv_scores}; Mean: {cv_scores.mean()}")
# Out:
# Lasso - Score: [-26.06378853 -15.13638569 -15.28335157 -15.14738769 -24.80363651]; Mean: -19.28690999890673
# Ridge - Score: [-22.0248312  -15.29800474 -13.94530099 -15.44308331 -22.00115496]; Mean: -17.74247503999108
# SVR - Score: [-24.99129799 -11.477814   -11.17356492 -13.39220933 -26.02947096]; Mean: -17.412871439868507
# Random Forest - Score: [-14.26204918 -10.51627081 -10.01926586  -9.84310997 -12.06400904]; Mean: -11.340940971383196
# Gradient Boosting - Score: [-13.93908638  -9.25105791  -8.61374278 -12.29701007 -11.00399801]; Mean: -11.020979031052448

# %%
from sklearn.model_selection import GridSearchCV


# param_grid_rf = {
#     'n_estimators': [50, 100, 200],        # number of trees
#     'max_depth': [None, 10, 20, 30],        # maximum depth of each tree
#     'max_features': ['sqrt', 'log2', None], # number of features to consider when looking for best split
#     'bootstrap': [True, False]              # whether bootstrap samples are used
# }

param_grid_gb = {
    'n_estimators': [25, 50, 100, 200],  # Number of trees
    'learning_rate': [0.01, 0.05, 0.1, 0.2],  # Learning rate
    # 'max_depth': [3, 4, 5, 6],  # Depth of trees
    # 'min_samples_split': [2, 5, 10],  # Min samples to split
    # 'min_samples_leaf': [1, 2, 4],  # Min samples per leaf
    # 'subsample': [0.7, 0.8, 0.9, 1.0],  # Subsample for stochastic gradient boosting
    'loss': ['squared_error', 'absolute_error', 'huber'],  # Loss function
    'max_features': [None, 'sqrt', 'log2']  # Number of features to consider for each split
}

# rf = RandomForestRegressor(random_state=42)
gb = GradientBoostingRegressor(random_state=42)

# grid_search = GridSearchCV(estimator=rf,
#                            param_grid=param_grid_rf,
#                            cv=kfold,
#                            n_jobs=-1,
#                            verbose=2,
#                            scoring='neg_mean_squared_error')

grid_search = GridSearchCV(estimator=gb,
                           param_grid=param_grid_gb,
                           cv=kfold,
                           n_jobs=-1,
                           verbose=2,
                           scoring='neg_mean_squared_error')

# Fit to training data
grid_search.fit(X_train_resampled, y_train)

# Best parameters
print("Best Parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=None, n_estimators=200; total time=   0.5s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.2s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.01, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.01, loss=huber, max_features=None, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, loss=huber, max_features=sqrt, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.01, loss=huber, max_features=log2, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s[CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
#
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=200; total time=   0.5s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=None, n_estimators=200; total time=   0.5s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.2s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.6s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.6s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.6s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.05, loss=huber, max_features=None, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=huber, max_features=sqrt, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.05, loss=huber, max_features=log2, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.1, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.6s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.6s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.1, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# ...
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=None, n_estimators=200; total time=   0.5s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=None, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=None, n_estimators=200; total time=   0.5s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=25; total time=   0.0s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=sqrt, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.3s
# [CV] END learning_rate=0.2, loss=squared_error, max_features=log2, n_estimators=200; total time=   0.4s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=None, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=sqrt, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=100; total time=   0.3s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.2, loss=absolute_error, max_features=log2, n_estimators=200; total time=   0.7s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=100; total time=   0.7s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s[CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=25; total time=   0.1s
#
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=huber, max_features=None, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=25; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=25; total time=   0.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=25; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=200; total time=   1.0s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=50; total time=   0.2s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=50; total time=   0.4s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=50; total time=   0.3s
# [CV] END learning_rate=0.2, loss=huber, max_features=sqrt, n_estimators=200; total time=   1.1s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=100; total time=   0.4s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=100; total time=   0.6s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=200; total time=   0.8s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=200; total time=   0.6s
# [CV] END learning_rate=0.2, loss=huber, max_features=log2, n_estimators=200; total time=   0.7s
# Best Parameters: {'learning_rate': 0.05, 'loss': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
grid_search.best_estimator_
# Out:
# GradientBoostingRegressor(learning_rate=0.05, max_features='sqrt',
#                           random_state=42)

# %%
import joblib

model_name = 'wpp_model_isqa.pkl'

joblib.dump(grid_search.best_estimator_, model_name)
# Out:
# ['wpp_model_isqa.pkl']

# %%
# Load the model
loaded_model = joblib.load(model_name)

# Make predictions
y_pred = loaded_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

yhat = loaded_model.predict(X_test)
print("MSE is", mean_squared_error(y_test, yhat))

print("R2 score is", r2_score(y_test, yhat))
# Out:
# MSE is 10.09741870833521
# R2 score is 0.8114195721291108

# %%
errors = y_test - yhat

# Plotting errors
plt.figure(figsize=(6, 4))

# Plotting error distribution
plt.hist(errors, bins=30, edgecolor='black', alpha=0.7, color='skyblue')
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.title('Error Distribution (Actual - Predicted)')
plt.show()

# %%
df_comparison = pd.DataFrame({
    'Actual_ISQA': y_test,
    'Predicted_ISQA': y_pred
})

df_comparison['Error'] = df_comparison['Actual_ISQA'] - df_comparison['Predicted_ISQA']
df_comparison.sort_values(by='Error', ascending=False)
# Out:
#      Actual_ISQA  Predicted_ISQA      Error
# 137    51.712500       36.504768  15.207732
# 141    46.425000       36.354752  10.070248
# 107    75.000000       65.031840   9.968160
# 210    42.300000       35.513105   6.786895
# 425    34.223637       28.171365   6.052272
# ..           ...             ...        ...
# 541    17.513908       21.648181  -4.134273
# 598    20.392645       24.626012  -4.233367
# 866    26.756775       31.138167  -4.381392
# 593    24.182559       28.681151  -4.498592
# 44     25.680368       31.492890  -5.812521
#
# [138 rows x 3 columns]
